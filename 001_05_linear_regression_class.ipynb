# %% [markdown]
# <a href="https://colab.research.google.com/github/KyeongHoSeong/rl_studios/blob/main/001_05_linear_regression_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reference: [PyTorch로 시작하는 딥 러닝 입문-3.2]-(https://wikidocs.net/60036)

# %% [markdown]
# # 모델을 클래스로 구현하기
#
# 1.모델을 선언 및 초기화. input_dim=1, output_dim=1.
#     model = nn.Linear(1,1)
# 2.클래스 구현
#
#     # torch.nn.Module을 상속받는 파이썬 클래스
#     class LinearRegressionModel(nn.Module):
#         def __init__(self): #
#             super().__init__()
#             # 단순 선형 회귀이므로 input_dim=1, output_dim=1.
#             self.linear = nn.Linear(1, 1)
#
#         def forward(self, x):
#             return self.linear(x)
#
#       model = LinearRegressionModel()
#
# 1. 클래스(class) 형태의 모델은 nn.Module 을 상속
# 2. __init__()에서 모델의 구조와 동적을 정의하는 생성자
#   -  파이썬에서 객체가 갖는 속성값을 초기화하는 역할로, 객체가 생성될 때 자동으호 호출
#    - super() 함수를 부르면 여기서 만든 클래스는 nn.Module 클래스의 속성들을 가지고 초기화
# 3. foward() 함수는 모델이 학습데이터를 입력받아서 forward 연산을 진행시키는 함수
#   -  forward() 함수는 model 객체를 데이터와 함께 호출하면 자동으로 실행
#   - ex: model(입력 데이터) --> 자동 forward 연산
#
# *** H(x) 식에 입력 x로부터 예측된 y를 얻는 것이 forward 연산

# %% [markdown]
# # A. 단순 선형 회귀  클라스 구현하기

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

torch.manual_seed(1)

# %% [markdown]
# 1.Data

# %%
# data : y = 2x 
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %% [markdown]
# 2. Class

# %%
class LinearRegressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(1,1)

  def forward(self, x):
    return self.linear(x)

# %% [markdown]
# 3. Model

# %%
model = LinearRegressionModel()

# %% [markdown]
# 4. Optimizer

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# 5. Training

# %%
epoches = 5000

for epoch in range(epoches):

  # H(x)
  prediction = model(x_train)

  # cost
  cost = F.mse_loss(prediction, y_train)

  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  if epoch % 100 == 0:
    # 100번마다 로그 출력
      print('Epoch {:4d}/{} Cost: {:.6f}'.format(
          epoch, epoches, cost.item()
      ))
# Out:
# Epoch    0/5000 Cost: 15.171722
# Epoch  100/5000 Cost: 15.171722
# Epoch  200/5000 Cost: 15.171722
# Epoch  300/5000 Cost: 15.171722
# Epoch  400/5000 Cost: 15.171722
# Epoch  500/5000 Cost: 15.171722
# Epoch  600/5000 Cost: 15.171722
# Epoch  700/5000 Cost: 15.171722
# Epoch  800/5000 Cost: 15.171722
# Epoch  900/5000 Cost: 15.171722
# Epoch 1000/5000 Cost: 15.171722
# Epoch 1100/5000 Cost: 15.171722
# Epoch 1200/5000 Cost: 15.171722
# Epoch 1300/5000 Cost: 15.171722
# Epoch 1400/5000 Cost: 15.171722
# Epoch 1500/5000 Cost: 15.171722
# Epoch 1600/5000 Cost: 15.171722
# Epoch 1700/5000 Cost: 15.171722
# Epoch 1800/5000 Cost: 15.171722
# Epoch 1900/5000 Cost: 15.171722
# Epoch 2000/5000 Cost: 15.171722
# Epoch 2100/5000 Cost: 15.171722
# Epoch 2200/5000 Cost: 15.171722
# Epoch 2300/5000 Cost: 15.171722
# Epoch 2400/5000 Cost: 15.171722
# Epoch 2500/5000 Cost: 15.171722
# Epoch 2600/5000 Cost: 15.171722
# Epoch 2700/5000 Cost: 15.171722
# Epoch 2800/5000 Cost: 15.171722
# ...

# %% [markdown]
# # B. 다중 선형 회기 구현하기

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

torch.manual_seed(1)

# %% [markdown]
# 1. data

# %%
# 데이터
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %% [markdown]
# 2. class

# %%
class MulitvaariateLinearRegressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(3,1)

  def forward(self, x):
    return self.linear(x)

# %% [markdown]
# 3. Model

# %%
model = MulitvaariateLinearRegressionModel()

# %% [markdown]
# 4. optimizer

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %% [markdown]
# 5. training

# %%
epoches = 2000

for epoch in range(epoches):
  # Hx
  prediction = model(x_train)

  # cost
  cost = F.mse_loss(prediction, y_train)

  # 
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  if epoch % 100 == 0:
    # 100번마다 로그 출력
      print('Epoch {:4d}/{} Cost: {:.6f}'.format(
          epoch, epoces, cost.item()
      ))
# Out:
# Epoch    0/2000 Cost: 39633.414062
# Epoch  100/2000 Cost: 11.480758
# Epoch  200/2000 Cost: 10.894581
# Epoch  300/2000 Cost: 10.339350
# Epoch  400/2000 Cost: 9.813331
# Epoch  500/2000 Cost: 9.315022
# Epoch  600/2000 Cost: 8.842963
# Epoch  700/2000 Cost: 8.395709
# Epoch  800/2000 Cost: 7.972028
# Epoch  900/2000 Cost: 7.570637
# Epoch 1000/2000 Cost: 7.190352
# Epoch 1100/2000 Cost: 6.830102
# Epoch 1200/2000 Cost: 6.488778
# Epoch 1300/2000 Cost: 6.165444
# Epoch 1400/2000 Cost: 5.859081
# Epoch 1500/2000 Cost: 5.568858
# Epoch 1600/2000 Cost: 5.293890
# Epoch 1700/2000 Cost: 5.033367
# Epoch 1800/2000 Cost: 4.786523
# Epoch 1900/2000 Cost: 4.552664
